# %%
import random

# Define parameters for the compressor
parameters = {
    "blade_angle": (10, 30),  # Range of blade angles (degrees)
    "airflow_rate": (50, 150),  # Range of airflow rates (kg/s)
    "pressure_ratio": (10, 20)  # Range of pressure ratios
}

# Fitness function (example: maximize efficiency)
def fitness(solution):
    blade_angle, airflow_rate, pressure_ratio = solution
    # Simulated efficiency formula (replace with actual physics-based model)
    efficiency = (
        0.8 * blade_angle
        + 0.5 * airflow_rate
        - 0.2 * pressure_ratio
        - 0.01 * abs(blade_angle - 20)  # Penalize deviation from optimal angle
    )
    return efficiency

# Initialize population
def initialize_population(size):
    population = []
    for _ in range(size):
        individual = [
            random.uniform(parameters["blade_angle"][0], parameters["blade_angle"][1]),
            random.uniform(parameters["airflow_rate"][0], parameters["airflow_rate"][1]),
            random.uniform(parameters["pressure_ratio"][0], parameters["pressure_ratio"][1])
        ]
        population.append(individual)
    return population

# Selection (select top individuals)
def select_parents(population, fitness_scores, num_parents):
    parents = [population[i] for i in sorted(range(len(fitness_scores)), key=lambda x: fitness_scores[x], reverse=True)[:num_parents]]
    return parents

# Crossover (combine two parents to create offspring)
def crossover(parent1, parent2):
    crossover_point = random.randint(1, len(parent1) - 1)
    child1 = parent1[:crossover_point] + parent2[crossover_point:]
    child2 = parent2[:crossover_point] + parent1[crossover_point:]
    return child1, child2

# Mutation (introduce random changes)
def mutate(individual, mutation_rate=0.1):
    for i in range(len(individual)):
        if random.random() < mutation_rate:
            individual[i] += random.uniform(-1, 1)  # Small random change
            # Ensure parameters stay within bounds
            individual[i] = max(parameters[list(parameters.keys())[i]][0], min(individual[i], parameters[list(parameters.keys())[i]][1]))
    return individual

# Main GA loop
def genetic_algorithm(pop_size, generations):
    population = initialize_population(pop_size)
    for generation in range(generations):
        fitness_scores = [fitness(individual) for individual in population]
        parents = select_parents(population, fitness_scores, pop_size // 2)
        next_generation = []
        for i in range(0, len(parents), 2):
            child1, child2 = crossover(parents[i], parents[i + 1])
            next_generation.append(mutate(child1))
            next_generation.append(mutate(child2))
        population = next_generation
        print(f"Generation {generation + 1}: Best Fitness = {max(fitness_scores)}")
    best_solution = population[fitness_scores.index(max(fitness_scores))]
    return best_solution

# Run GA
best_params = genetic_algorithm(pop_size=20, generations=50)
print("Optimized Parameters:", best_params)
# Out:
# Generation 1: Best Fitness = 86.00389431927876
# Generation 2: Best Fitness = 87.55888170772786
# Generation 3: Best Fitness = 87.43784780473682
# Generation 4: Best Fitness = 87.81604733275175
# Generation 5: Best Fitness = 89.7375010778255
# Generation 6: Best Fitness = 88.09673062256992
# Generation 7: Best Fitness = 89.32444737549002
# Generation 8: Best Fitness = 89.30980099524078
# Generation 9: Best Fitness = 91.19110567749078
# Generation 10: Best Fitness = 91.06034734179806
# Generation 11: Best Fitness = 89.94285634525195
# Generation 12: Best Fitness = 90.47685156568625
# Generation 13: Best Fitness = 92.77697272533402
# Generation 14: Best Fitness = 92.74203286919143
# Generation 15: Best Fitness = 92.6462143896413
# Generation 16: Best Fitness = 91.06034734179806
# Generation 17: Best Fitness = 92.6462143896413
# Generation 18: Best Fitness = 91.06034734179806
# Generation 19: Best Fitness = 91.1561658213482
# Generation 20: Best Fitness = 91.06034734179806
# Generation 21: Best Fitness = 92.52784943869739
# Generation 22: Best Fitness = 90.77806668400959
# Generation 23: Best Fitness = 92.52784943869739
# Generation 24: Best Fitness = 90.77806668400959
# Generation 25: Best Fitness = 92.52784943869739
# Generation 26: Best Fitness = 90.78342873177587
# Generation 27: Best Fitness = 92.52784943869739
# Generation 28: Best Fitness = 92.87738042455773
# Generation 29: Best Fitness = 92.52784943869739
# Generation 30: Best Fitness = 92.87738042455773
# Generation 31: Best Fitness = 92.52784943869739
# Generation 32: Best Fitness = 93.0072702818347
# Generation 33: Best Fitness = 90.42663524509277
# Generation 34: Best Fitness = 90.90605608823009
# Generation 35: Best Fitness = 91.13208808139836
# Generation 36: Best Fitness = 91.98959015271157
# Generation 37: Best Fitness = 91.0428444662193
# Generation 38: Best Fitness = 91.52226530935661
# Generation 39: Best Fitness = 90.45105604070126
# Generation 40: Best Fitness = 93.88599968028629
# Generation 41: Best Fitness = 90.45105604070126
# Generation 42: Best Fitness = 91.1083624440146
# Generation 43: Best Fitness = 93.22869327697295
# Generation 44: Best Fitness = 93.88599968028629
# Generation 45: Best Fitness = 92.27714486342454
# Generation 46: Best Fitness = 91.22533239921194
# Generation 47: Best Fitness = 92.00924548534707
# Generation 48: Best Fitness = 93.73893430509209
# Generation 49: Best Fitness = 92.95502121895696
# Generation 50: Best Fitness = 91.49323177728942
# Optimized Parameters: [26.415443505444493, 150, 14.830568875749925]

# %%
# !pip install gym
# !pip install shimmy
# !pip install stable_baselines3
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Requirement already satisfied: gym in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from gym) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym) (3.1.1)
# Requirement already satisfied: gym_notices>=0.0.4 in /usr/local/lib/python3.11/dist-packages (from gym) (0.0.8)
# Requirement already satisfied: shimmy in /usr/local/lib/python3.11/dist-packages (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from shimmy) (1.26.4)
# Requirement already satisfied: gymnasium>=1.0.0a1 in /usr/local/lib/python3.11/dist-packages (from shimmy) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy) (0.0.4)
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.1.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.0.0)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.26.4)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.5.1+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.1.0,>=0.29.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2024.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3) (3.0.2)
# Downloading stable_baselines3-2.5.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 5.6 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 92.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 73.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable_baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable_baselines3-2.5.0

# %%
import numpy as np
import gym
from gym import spaces

# Custom Environment for SGT-400 Compressor
class CompressorEnv(gym.Env):
    def __init__(self):
        super(CompressorEnv, self).__init__()
        # Define action and observation space
        self.action_space = spaces.Box(low=np.array([10, 50]), high=np.array([30, 150]), dtype=np.float32)  # Blade angle, airflow rate
        self.observation_space = spaces.Box(low=np.array([0, 0]), high=np.array([100, 20]), dtype=np.float32)  # Temperature, pressure ratio

        # Initial state
        self.state = np.array([50, 15])  # Initial temperature and pressure ratio
        self.steps = 0

    def step(self, action):
        blade_angle, airflow_rate = action
        temperature, pressure_ratio = self.state

        # Simulate compressor dynamics (replace with actual physics-based model)
        new_temperature = temperature + 0.1 * airflow_rate - 0.05 * blade_angle
        new_pressure_ratio = pressure_ratio + 0.02 * blade_angle - 0.01 * airflow_rate

        # Update state
        self.state = np.array([new_temperature, new_pressure_ratio])

        # Calculate reward (efficiency improvement)
        reward = 0.8 * new_temperature - 0.2 * new_pressure_ratio

        # Check if episode is done
        self.steps += 1
        done = self.steps >= 100  # Episode ends after 100 steps

        return self.state, reward, done, {}

    def reset(self):
        self.state = np.array([50, 15])  # Reset to initial state
        self.steps = 0
        return self.state

# Train RL Agent using Stable-Baselines3
from stable_baselines3 import PPO

# Create environment
env = CompressorEnv()

# Train PPO agent
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)

# Test the trained agent
obs = env.reset()
for _ in range(100):
    action, _states = model.predict(obs)
    obs, reward, done, info = env.step(action)
    print(f"Action: {action}, State: {obs}, Reward: {reward}")
    if done:
        obs = env.reset()
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 2.22e+04 |
# | time/              |          |
# |    fps             | 1073     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 2.22e+04     |
# | time/                   |              |
# |    fps                  | 937          |
# |    iterations           | 2            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0043311045 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -7.84e-05    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.62e+06     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00234     |
# |    std                  | 1            |
# |    value_loss           | 1.29e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 2.22e+04     |
# | time/                   |              |
# |    fps                  | 900          |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0046526976 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 1.06e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.99e+06     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00384     |
# |    std                  | 0.997        |
# |    value_loss           | 1.32e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 2.22e+04      |
# | time/                   |               |
# |    fps                  | 885           |
# |    iterations           | 4             |
# |    time_elapsed         | 9             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00016703241 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.83         |
# |    explained_variance   | 4.05e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.96e+06      |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -1.78e-05     |
# |    std                  | 1             |
# |    value_loss           | 1.29e+07      |
# -------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 100        |
# |    ep_rew_mean          | 2.22e+04   |
# | time/                   |            |
# |    fps                  | 873        |
# |    iterations           | 5          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00327825 |
# |    clip_fraction        | 0.00786    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.84      |
# |    explained_variance   | 2.44e-06   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.7e+06    |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00154   |
# |    std                  | 1          |
# |    value_loss           | 1.31e+07   |
# ----------------------------------------
# Action: [10. 50.], State: [54.5 14.7], Reward: 40.660000000000004
# Action: [10. 50.], State: [59.  14.4], Reward: 44.32
# Action: [10. 50.], State: [63.5 14.1], Reward: 47.980000000000004
# Action: [10. 50.], State: [68.  13.8], Reward: 51.64000000000001
# Action: [10. 50.], State: [72.5 13.5], Reward: 55.3
# Action: [10. 50.], State: [77.  13.2], Reward: 58.96
# Action: [10. 50.], State: [81.5 12.9], Reward: 62.620000000000005
# Action: [10. 50.], State: [86.  12.6], Reward: 66.28
# Action: [10. 50.], State: [90.5 12.3], Reward: 69.94000000000001
# Action: [10. 50.], State: [95. 12.], Reward: 73.6
# Action: [10. 50.], State: [99.5 11.7], Reward: 77.26
# Action: [10. 50.], State: [104.   11.4], Reward: 80.92
# Action: [10. 50.], State: [108.5  11.1], Reward: 84.58000000000001
# Action: [10. 50.], State: [113.   10.8], Reward: 88.24000000000001
# Action: [10. 50.], State: [117.5  10.5], Reward: 91.9
# Action: [10. 50.], State: [122.   10.2], Reward: 95.56000000000002
# Action: [10. 50.], State: [126.5   9.9], Reward: 99.22
# Action: [10. 50.], State: [131.    9.6], Reward: 102.88000000000001
# Action: [10. 50.], State: [135.5   9.3], Reward: 106.54
# Action: [10. 50.], State: [140.   9.], Reward: 110.2
# Action: [10. 50.], State: [144.5   8.7], Reward: 113.86000000000001
# Action: [10. 50.], State: [149.    8.4], Reward: 117.52000000000001
# Action: [10. 50.], State: [153.5   8.1], Reward: 121.18000000000002
# Action: [10. 50.], State: [158.    7.8], Reward: 124.84
# Action: [10. 50.], State: [162.5   7.5], Reward: 128.5
# Action: [10. 50.], State: [167.    7.2], Reward: 132.16
# Action: [10. 50.], State: [171.5   6.9], Reward: 135.82000000000002
# Action: [10. 50.], State: [176.    6.6], Reward: 139.48000000000002
# Action: [10. 50.], State: [180.5   6.3], Reward: 143.14000000000001
# Action: [10. 50.], State: [185.   6.], Reward: 146.8
# Action: [10. 50.], State: [189.5   5.7], Reward: 150.46
# Action: [10. 50.], State: [194.    5.4], Reward: 154.12000000000003
# Action: [10. 50.], State: [198.5   5.1], Reward: 157.78
# Action: [10. 50.], State: [203.    4.8], Reward: 161.44
# Action: [10. 50.], State: [207.5   4.5], Reward: 165.1
# Action: [10. 50.], State: [212.    4.2], Reward: 168.76000000000002
# Action: [10. 50.], State: [216.5   3.9], Reward: 172.42000000000002
# Action: [10. 50.], State: [221.    3.6], Reward: 176.08
# Action: [10. 50.], State: [225.5   3.3], Reward: 179.74
# Action: [10. 50.], State: [230.   3.], Reward: 183.4
# Action: [10. 50.], State: [234.5   2.7], Reward: 187.06000000000003
# Action: [10. 50.], State: [239.    2.4], Reward: 190.72000000000003
# Action: [10. 50.], State: [243.5   2.1], Reward: 194.38000000000002
# Action: [10. 50.], State: [248.    1.8], Reward: 198.04000000000002
# Action: [10. 50.], State: [252.5   1.5], Reward: 201.7
# Action: [10. 50.], State: [257.    1.2], Reward: 205.36
# Action: [10. 50.], State: [261.5   0.9], Reward: 209.02
# Action: [10. 50.], State: [266.    0.6], Reward: 212.68
# Action: [10. 50.], State: [270.5   0.3], Reward: 216.34
# Action: [10. 50.], State: [ 2.75000000e+02 -1.37112544e-14], Reward: 220.0
# Action: [10. 50.], State: [279.5  -0.3], Reward: 223.66000000000003
# Action: [10. 50.], State: [284.   -0.6], Reward: 227.32000000000002
# Action: [10. 50.], State: [288.5  -0.9], Reward: 230.98000000000002
# Action: [10. 50.], State: [293.   -1.2], Reward: 234.64000000000001
# Action: [10. 50.], State: [297.5  -1.5], Reward: 238.3
# Action: [10. 50.], State: [302.   -1.8], Reward: 241.96000000000004
# Action: [10. 50.], State: [306.5  -2.1], Reward: 245.62000000000003
# Action: [10. 50.], State: [311.   -2.4], Reward: 249.28
# Action: [10. 50.], State: [315.5  -2.7], Reward: 252.94
# Action: [10. 50.], State: [320.  -3.], Reward: 256.6
# Action: [10. 50.], State: [324.5  -3.3], Reward: 260.26000000000005
# Action: [10. 50.], State: [329.   -3.6], Reward: 263.92
# Action: [10. 50.], State: [333.5  -3.9], Reward: 267.58000000000004
# Action: [10. 50.], State: [338.   -4.2], Reward: 271.24
# Action: [10. 50.], State: [342.5  -4.5], Reward: 274.9
# Action: [10. 50.], State: [347.   -4.8], Reward: 278.56
# Action: [10. 50.], State: [351.5  -5.1], Reward: 282.21999999999997
# Action: [10. 50.], State: [356.   -5.4], Reward: 285.88
# Action: [10. 50.], State: [360.5  -5.7], Reward: 289.54
# Action: [10. 50.], State: [365.  -6.], Reward: 293.2
# Action: [10. 50.], State: [369.5  -6.3], Reward: 296.86
# Action: [10. 50.], State: [374.   -6.6], Reward: 300.52
# Action: [10. 50.], State: [378.5  -6.9], Reward: 304.18
# Action: [10. 50.], State: [383.   -7.2], Reward: 307.84000000000003
# Action: [10. 50.], State: [387.5  -7.5], Reward: 311.5
# Action: [10. 50.], State: [392.   -7.8], Reward: 315.16
# Action: [10. 50.], State: [396.5  -8.1], Reward: 318.82000000000005
# Action: [10. 50.], State: [401.   -8.4], Reward: 322.48
# Action: [10. 50.], State: [405.5  -8.7], Reward: 326.14000000000004
# Action: [10. 50.], State: [410.  -9.], Reward: 329.8
# Action: [10. 50.], State: [414.5  -9.3], Reward: 333.46000000000004
# Action: [10. 50.], State: [419.   -9.6], Reward: 337.12000000000006
# Action: [10. 50.], State: [423.5  -9.9], Reward: 340.78000000000003
# Action: [10. 50.], State: [428.  -10.2], Reward: 344.44000000000005
# Action: [10. 50.], State: [432.5 -10.5], Reward: 348.1
# Action: [10. 50.], State: [437.  -10.8], Reward: 351.76000000000005
# Action: [10. 50.], State: [441.5 -11.1], Reward: 355.4200000000001
# Action: [10. 50.], State: [446.  -11.4], Reward: 359.08000000000004
# Action: [10. 50.], State: [450.5 -11.7], Reward: 362.74
# Action: [10. 50.], State: [455. -12.], Reward: 366.4
# Action: [10. 50.], State: [459.5 -12.3], Reward: 370.06
# Action: [10. 50.], State: [464.  -12.6], Reward: 373.72
# Action: [10. 50.], State: [468.5 -12.9], Reward: 377.38
# Action: [10. 50.], State: [473.  -13.2], Reward: 381.04
# Action: [10. 50.], State: [477.5 -13.5], Reward: 384.7
# Action: [10. 50.], State: [482.  -13.8], Reward: 388.36
# Action: [10. 50.], State: [486.5 -14.1], Reward: 392.02000000000004
# Action: [10. 50.], State: [491.  -14.4], Reward: 395.68
# Action: [10. 50.], State: [495.5 -14.7], Reward: 399.34000000000003
# Action: [10. 50.], State: [500. -15.], Reward: 403.0

# %% [markdown]
# ### **خروجی نمونه:**
# ```plaintext
# Action: [25.3, 120.7], State: [58.6, 16.2], Reward: 43.5
# Action: [26.1, 118.4], State: [60.2, 16.5], Reward: 45.1
# Action: [24.8, 122.3], State: [61.8, 16.8], Reward: 46.7
# ...
# Action: [27.5, 115.9], State: [72.4, 18.3], Reward: 52.3
# ```
#
# ---
#
# ### **توضیح خروجی به زبان فارسی:**
#
# 1. **Action: [25.3, 120.7]**
#    - این بخش نشان‌دهنده‌ی **عملیاتی که عامل (Agent)** انجام داده است.
#    - عملیات شامل دو پارامتر است:
#      - **زاویه‌ی پره (Blade Angle):** `25.3` درجه
#      - **نرخ جریان هوا (Airflow Rate):** `120.7` کیلوگرم بر ثانیه
#
# 2. **State: [58.6, 16.2]**
#    - این بخش نشان‌دهنده‌ی **وضعیت فعلی سیستم (State)** است.
#    - وضعیت شامل دو پارامتر است:
#      - **دمای فعلی (Temperature):** `58.6` درجه سانتی‌گراد
#      - **نسبت فشار (Pressure Ratio):** `16.2`
#
# 3. **Reward: 43.5**
#    - این عدد نشان‌دهنده‌ی **پاداش (Reward)** است که عامل برای عملیات انجام‌شده دریافت کرده است.
#    - پاداش معیاری است که نشان می‌دهد عملیات انجام‌شده چقدر خوب بوده است. در اینجا، عدد `43.5` نشان می‌دهد که عملیات منجر به بهبود راندمان شده است.
#
# ---
#
# ### **خلاصه به زبان ساده:**
# - **عملیات (Action):**
#   عامل تصمیم گرفته است که زاویه‌ی پره را روی `25.3` درجه و نرخ جریان هوا را روی `120.7` کیلوگرم بر ثانیه تنظیم کند.
#
# - **وضعیت (State):**
#   بعد از انجام عملیات، دما به `58.6` درجه و نسبت فشار به `16.2` رسیده است.
#
# - **پاداش (Reward):**
#   عملیات انجام‌شده باعث شده است که عامل `43.5` امتیاز پاداش دریافت کند. این نشان می‌دهد که عملیات تأثیر مثبتی بر عملکرد کمپرسور داشته است.
#
# ---
#
# ### **نتیجه‌گیری کلی:**
# - **هدف:**
#   هدف اصلی عامل (Agent) این است که با تنظیم پارامترهای کمپرسور (مثل زاویه‌ی پره و نرخ جریان هوا)، به حداکثر راندمان برسد و پاداش بیشتری دریافت کند.
#
# - **بهینه‌سازی:**
#   در طول ۱۰۰ مرحله (Steps)، عامل یاد می‌گیرد که چگونه پارامترها را تنظیم کند تا بهترین عملکرد از کمپرسور SGT-400 به دست آید.
#
# - **نتایج نهایی:**
#   در انتهای آموزش، عامل قادر خواهد بود که پارامترهای بهینه‌ای را پیدا کند که منجر به بالاترین راندمان و کمترین مصرف انرژی شود.

# %%
import numpy as np
import gym
from gym import spaces

# محیط سفارشی برای کمپرسور SGT-400
class CompressorEnv(gym.Env):
    def __init__(self):
        super(CompressorEnv, self).__init__()
        # تعریف فضای عملیات و مشاهدات
        self.action_space = spaces.Box(low=np.array([10, 50]), high=np.array([30, 150]), dtype=np.float32)  # زاویه‌ی پره، نرخ جریان هوا
        self.observation_space = spaces.Box(low=np.array([0, 0]), high=np.array([100, 20]), dtype=np.float32)  # دما، نسبت فشار
        # حالت اولیه
        self.state = np.array([50, 15])  # دمای اولیه و نسبت فشار اولیه
        self.steps = 0

    def step(self, action):
        blade_angle, airflow_rate = action
        temperature, pressure_ratio = self.state
        # شبیه‌سازی دینامیک کمپرسور (جایگزینی با مدل فیزیکی واقعی)
        new_temperature = temperature + 0.1 * airflow_rate - 0.05 * blade_angle
        new_pressure_ratio = pressure_ratio + 0.02 * blade_angle - 0.01 * airflow_rate
        # به‌روزرسانی حالت
        self.state = np.array([new_temperature, new_pressure_ratio])
        # محاسبه پاداش (بهبود راندمان)
        reward = 0.8 * new_temperature - 0.2 * new_pressure_ratio
        # بررسی پایان دوره
        self.steps += 1
        done = self.steps >= 100  # دوره پس از ۱۰۰ مرحله به پایان می‌رسد
        return self.state, reward, done, {}

    def reset(self):
        self.state = np.array([50, 15])  # بازنشانی به حالت اولیه
        self.steps = 0
        return self.state

# آموزش عامل RL با استفاده از Stable-Baselines3
from stable_baselines3 import PPO

# ایجاد محیط
env = CompressorEnv()

# آموزش عامل PPO
print("آموزش عامل PPO شروع شد...")
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)
print("آموزش عامل PPO به پایان رسید.")

# تست عامل آموزش‌دیده
obs = env.reset()
print("\nتست عامل آموزش‌دیده:")
for step in range(100):
    action, _states = model.predict(obs)
    obs, reward, done, info = env.step(action)

    # نمایش نتایج به زبان فارسی
    print(f"مرحله {step + 1}:")
    print(f"عملیات انجام‌شده: زاویه‌ی پره = {action[0]:.2f} درجه, نرخ جریان هوا = {action[1]:.2f} کیلوگرم بر ثانیه")
    print(f"وضعیت فعلی: دما = {obs[0]:.2f} درجه سانتی‌گراد, نسبت فشار = {obs[1]:.2f}")
    print(f"امتیاز عملکرد (Reward): {reward:.2f}\n")

    if done:
        obs = env.reset()
# Out:
# /usr/local/lib/python3.11/dist-packages/gym/spaces/box.py:128: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# آموزش عامل PPO شروع شد...
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 2.22e+04 |
# | time/              |          |
# |    fps             | 1515     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 2.22e+04     |
# | time/                   |              |
# |    fps                  | 1048         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0029931217 |
# |    clip_fraction        | 0.00356      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | -0.000204    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.47e+06     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00095     |
# |    std                  | 1            |
# |    value_loss           | 1.29e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 2.22e+04     |
# | time/                   |              |
# |    fps                  | 883          |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0034533935 |
# |    clip_fraction        | 0.00317      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 1.25e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.26e+06     |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00104     |
# |    std                  | 1            |
# |    value_loss           | 1.32e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 2.22e+04     |
# | time/                   |              |
# |    fps                  | 792          |
# |    iterations           | 4            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0008796591 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.84        |
# |    explained_variance   | 2.5e-06      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.12e+06     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000738    |
# |    std                  | 1            |
# |    value_loss           | 1.29e+07     |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 100           |
# |    ep_rew_mean          | 2.22e+04      |
# | time/                   |               |
# |    fps                  | 796           |
# |    iterations           | 5             |
# |    time_elapsed         | 12            |
# |    total_timesteps      | 10240         |
# | train/                  |               |
# |    approx_kl            | 0.00045658555 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.84         |
# |    explained_variance   | 1.19e-06      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 7e+06         |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.000193     |
# |    std                  | 1             |
# |    value_loss           | 1.31e+07      |
# -------------------------------------------
# آموزش عامل PPO به پایان رسید.
#
# تست عامل آموزش‌دیده:
# مرحله 1:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 54.50 درجه سانتی‌گراد, نسبت فشار = 14.70
# امتیاز عملکرد (Reward): 40.66
#
# مرحله 2:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 59.00 درجه سانتی‌گراد, نسبت فشار = 14.40
# امتیاز عملکرد (Reward): 44.32
#
# مرحله 3:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 63.50 درجه سانتی‌گراد, نسبت فشار = 14.10
# امتیاز عملکرد (Reward): 47.98
#
# مرحله 4:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 68.00 درجه سانتی‌گراد, نسبت فشار = 13.80
# امتیاز عملکرد (Reward): 51.64
#
# مرحله 5:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 72.50 درجه سانتی‌گراد, نسبت فشار = 13.50
# امتیاز عملکرد (Reward): 55.30
#
# مرحله 6:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 77.00 درجه سانتی‌گراد, نسبت فشار = 13.20
# امتیاز عملکرد (Reward): 58.96
#
# مرحله 7:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 81.50 درجه سانتی‌گراد, نسبت فشار = 12.90
# امتیاز عملکرد (Reward): 62.62
#
# مرحله 8:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 86.00 درجه سانتی‌گراد, نسبت فشار = 12.60
# امتیاز عملکرد (Reward): 66.28
#
# مرحله 9:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 90.50 درجه سانتی‌گراد, نسبت فشار = 12.30
# امتیاز عملکرد (Reward): 69.94
#
# مرحله 10:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 95.00 درجه سانتی‌گراد, نسبت فشار = 12.00
# امتیاز عملکرد (Reward): 73.60
#
# مرحله 11:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 99.50 درجه سانتی‌گراد, نسبت فشار = 11.70
# امتیاز عملکرد (Reward): 77.26
#
# مرحله 12:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 104.00 درجه سانتی‌گراد, نسبت فشار = 11.40
# امتیاز عملکرد (Reward): 80.92
#
# مرحله 13:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 108.50 درجه سانتی‌گراد, نسبت فشار = 11.10
# امتیاز عملکرد (Reward): 84.58
#
# مرحله 14:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 113.00 درجه سانتی‌گراد, نسبت فشار = 10.80
# امتیاز عملکرد (Reward): 88.24
#
# مرحله 15:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 117.50 درجه سانتی‌گراد, نسبت فشار = 10.50
# امتیاز عملکرد (Reward): 91.90
#
# مرحله 16:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 122.00 درجه سانتی‌گراد, نسبت فشار = 10.20
# امتیاز عملکرد (Reward): 95.56
#
# مرحله 17:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 126.50 درجه سانتی‌گراد, نسبت فشار = 9.90
# امتیاز عملکرد (Reward): 99.22
#
# مرحله 18:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 131.00 درجه سانتی‌گراد, نسبت فشار = 9.60
# امتیاز عملکرد (Reward): 102.88
#
# مرحله 19:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 135.50 درجه سانتی‌گراد, نسبت فشار = 9.30
# امتیاز عملکرد (Reward): 106.54
#
# مرحله 20:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 140.00 درجه سانتی‌گراد, نسبت فشار = 9.00
# امتیاز عملکرد (Reward): 110.20
#
# مرحله 21:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 144.50 درجه سانتی‌گراد, نسبت فشار = 8.70
# امتیاز عملکرد (Reward): 113.86
#
# مرحله 22:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 149.00 درجه سانتی‌گراد, نسبت فشار = 8.40
# امتیاز عملکرد (Reward): 117.52
#
# مرحله 23:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 153.50 درجه سانتی‌گراد, نسبت فشار = 8.10
# امتیاز عملکرد (Reward): 121.18
#
# مرحله 24:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 158.00 درجه سانتی‌گراد, نسبت فشار = 7.80
# امتیاز عملکرد (Reward): 124.84
#
# مرحله 25:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 162.50 درجه سانتی‌گراد, نسبت فشار = 7.50
# امتیاز عملکرد (Reward): 128.50
#
# مرحله 26:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 167.00 درجه سانتی‌گراد, نسبت فشار = 7.20
# امتیاز عملکرد (Reward): 132.16
#
# مرحله 27:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 171.50 درجه سانتی‌گراد, نسبت فشار = 6.90
# امتیاز عملکرد (Reward): 135.82
#
# مرحله 28:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 176.00 درجه سانتی‌گراد, نسبت فشار = 6.60
# امتیاز عملکرد (Reward): 139.48
#
# مرحله 29:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 180.50 درجه سانتی‌گراد, نسبت فشار = 6.30
# امتیاز عملکرد (Reward): 143.14
#
# مرحله 30:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 185.00 درجه سانتی‌گراد, نسبت فشار = 6.00
# امتیاز عملکرد (Reward): 146.80
#
# مرحله 31:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 189.50 درجه سانتی‌گراد, نسبت فشار = 5.70
# امتیاز عملکرد (Reward): 150.46
#
# مرحله 32:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 194.00 درجه سانتی‌گراد, نسبت فشار = 5.40
# امتیاز عملکرد (Reward): 154.12
#
# مرحله 33:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 198.50 درجه سانتی‌گراد, نسبت فشار = 5.10
# امتیاز عملکرد (Reward): 157.78
#
# مرحله 34:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 203.00 درجه سانتی‌گراد, نسبت فشار = 4.80
# امتیاز عملکرد (Reward): 161.44
#
# مرحله 35:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 207.50 درجه سانتی‌گراد, نسبت فشار = 4.50
# امتیاز عملکرد (Reward): 165.10
#
# مرحله 36:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 212.00 درجه سانتی‌گراد, نسبت فشار = 4.20
# امتیاز عملکرد (Reward): 168.76
#
# مرحله 37:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 216.50 درجه سانتی‌گراد, نسبت فشار = 3.90
# امتیاز عملکرد (Reward): 172.42
#
# مرحله 38:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 221.00 درجه سانتی‌گراد, نسبت فشار = 3.60
# امتیاز عملکرد (Reward): 176.08
#
# مرحله 39:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 225.50 درجه سانتی‌گراد, نسبت فشار = 3.30
# امتیاز عملکرد (Reward): 179.74
#
# مرحله 40:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 230.00 درجه سانتی‌گراد, نسبت فشار = 3.00
# امتیاز عملکرد (Reward): 183.40
#
# مرحله 41:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 234.50 درجه سانتی‌گراد, نسبت فشار = 2.70
# امتیاز عملکرد (Reward): 187.06
#
# مرحله 42:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 239.00 درجه سانتی‌گراد, نسبت فشار = 2.40
# امتیاز عملکرد (Reward): 190.72
#
# مرحله 43:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 243.50 درجه سانتی‌گراد, نسبت فشار = 2.10
# امتیاز عملکرد (Reward): 194.38
#
# مرحله 44:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 248.00 درجه سانتی‌گراد, نسبت فشار = 1.80
# امتیاز عملکرد (Reward): 198.04
#
# مرحله 45:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 252.50 درجه سانتی‌گراد, نسبت فشار = 1.50
# امتیاز عملکرد (Reward): 201.70
#
# مرحله 46:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 257.00 درجه سانتی‌گراد, نسبت فشار = 1.20
# امتیاز عملکرد (Reward): 205.36
#
# مرحله 47:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 261.50 درجه سانتی‌گراد, نسبت فشار = 0.90
# امتیاز عملکرد (Reward): 209.02
#
# مرحله 48:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 266.00 درجه سانتی‌گراد, نسبت فشار = 0.60
# امتیاز عملکرد (Reward): 212.68
#
# مرحله 49:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 270.50 درجه سانتی‌گراد, نسبت فشار = 0.30
# امتیاز عملکرد (Reward): 216.34
#
# مرحله 50:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 275.00 درجه سانتی‌گراد, نسبت فشار = -0.00
# امتیاز عملکرد (Reward): 220.00
#
# مرحله 51:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 279.50 درجه سانتی‌گراد, نسبت فشار = -0.30
# امتیاز عملکرد (Reward): 223.66
#
# مرحله 52:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 284.00 درجه سانتی‌گراد, نسبت فشار = -0.60
# امتیاز عملکرد (Reward): 227.32
#
# مرحله 53:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 288.50 درجه سانتی‌گراد, نسبت فشار = -0.90
# امتیاز عملکرد (Reward): 230.98
#
# مرحله 54:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 293.00 درجه سانتی‌گراد, نسبت فشار = -1.20
# امتیاز عملکرد (Reward): 234.64
#
# مرحله 55:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 297.50 درجه سانتی‌گراد, نسبت فشار = -1.50
# امتیاز عملکرد (Reward): 238.30
#
# مرحله 56:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 302.00 درجه سانتی‌گراد, نسبت فشار = -1.80
# امتیاز عملکرد (Reward): 241.96
#
# مرحله 57:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 306.50 درجه سانتی‌گراد, نسبت فشار = -2.10
# امتیاز عملکرد (Reward): 245.62
#
# مرحله 58:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 311.00 درجه سانتی‌گراد, نسبت فشار = -2.40
# امتیاز عملکرد (Reward): 249.28
#
# مرحله 59:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 315.50 درجه سانتی‌گراد, نسبت فشار = -2.70
# امتیاز عملکرد (Reward): 252.94
#
# مرحله 60:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 320.00 درجه سانتی‌گراد, نسبت فشار = -3.00
# امتیاز عملکرد (Reward): 256.60
#
# مرحله 61:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 324.50 درجه سانتی‌گراد, نسبت فشار = -3.30
# امتیاز عملکرد (Reward): 260.26
#
# مرحله 62:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 329.00 درجه سانتی‌گراد, نسبت فشار = -3.60
# امتیاز عملکرد (Reward): 263.92
#
# مرحله 63:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 333.50 درجه سانتی‌گراد, نسبت فشار = -3.90
# امتیاز عملکرد (Reward): 267.58
#
# مرحله 64:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 338.00 درجه سانتی‌گراد, نسبت فشار = -4.20
# امتیاز عملکرد (Reward): 271.24
#
# مرحله 65:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 342.50 درجه سانتی‌گراد, نسبت فشار = -4.50
# امتیاز عملکرد (Reward): 274.90
#
# مرحله 66:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 347.00 درجه سانتی‌گراد, نسبت فشار = -4.80
# امتیاز عملکرد (Reward): 278.56
#
# مرحله 67:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 351.50 درجه سانتی‌گراد, نسبت فشار = -5.10
# امتیاز عملکرد (Reward): 282.22
#
# مرحله 68:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 356.00 درجه سانتی‌گراد, نسبت فشار = -5.40
# امتیاز عملکرد (Reward): 285.88
#
# مرحله 69:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 360.50 درجه سانتی‌گراد, نسبت فشار = -5.70
# امتیاز عملکرد (Reward): 289.54
#
# مرحله 70:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 365.00 درجه سانتی‌گراد, نسبت فشار = -6.00
# امتیاز عملکرد (Reward): 293.20
#
# مرحله 71:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 369.50 درجه سانتی‌گراد, نسبت فشار = -6.30
# امتیاز عملکرد (Reward): 296.86
#
# مرحله 72:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 374.00 درجه سانتی‌گراد, نسبت فشار = -6.60
# امتیاز عملکرد (Reward): 300.52
#
# مرحله 73:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 378.50 درجه سانتی‌گراد, نسبت فشار = -6.90
# امتیاز عملکرد (Reward): 304.18
#
# مرحله 74:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 383.00 درجه سانتی‌گراد, نسبت فشار = -7.20
# امتیاز عملکرد (Reward): 307.84
#
# مرحله 75:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 387.50 درجه سانتی‌گراد, نسبت فشار = -7.50
# امتیاز عملکرد (Reward): 311.50
#
# مرحله 76:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 392.00 درجه سانتی‌گراد, نسبت فشار = -7.80
# امتیاز عملکرد (Reward): 315.16
#
# مرحله 77:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 396.50 درجه سانتی‌گراد, نسبت فشار = -8.10
# امتیاز عملکرد (Reward): 318.82
#
# مرحله 78:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 401.00 درجه سانتی‌گراد, نسبت فشار = -8.40
# امتیاز عملکرد (Reward): 322.48
#
# مرحله 79:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 405.50 درجه سانتی‌گراد, نسبت فشار = -8.70
# امتیاز عملکرد (Reward): 326.14
#
# مرحله 80:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 410.00 درجه سانتی‌گراد, نسبت فشار = -9.00
# امتیاز عملکرد (Reward): 329.80
#
# مرحله 81:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 414.50 درجه سانتی‌گراد, نسبت فشار = -9.30
# امتیاز عملکرد (Reward): 333.46
#
# مرحله 82:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 419.00 درجه سانتی‌گراد, نسبت فشار = -9.60
# امتیاز عملکرد (Reward): 337.12
#
# مرحله 83:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 423.50 درجه سانتی‌گراد, نسبت فشار = -9.90
# امتیاز عملکرد (Reward): 340.78
#
# مرحله 84:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 428.00 درجه سانتی‌گراد, نسبت فشار = -10.20
# امتیاز عملکرد (Reward): 344.44
#
# مرحله 85:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 432.50 درجه سانتی‌گراد, نسبت فشار = -10.50
# امتیاز عملکرد (Reward): 348.10
#
# مرحله 86:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 437.00 درجه سانتی‌گراد, نسبت فشار = -10.80
# امتیاز عملکرد (Reward): 351.76
#
# مرحله 87:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 441.50 درجه سانتی‌گراد, نسبت فشار = -11.10
# امتیاز عملکرد (Reward): 355.42
#
# مرحله 88:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 446.00 درجه سانتی‌گراد, نسبت فشار = -11.40
# امتیاز عملکرد (Reward): 359.08
#
# مرحله 89:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 450.50 درجه سانتی‌گراد, نسبت فشار = -11.70
# امتیاز عملکرد (Reward): 362.74
#
# مرحله 90:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 455.00 درجه سانتی‌گراد, نسبت فشار = -12.00
# امتیاز عملکرد (Reward): 366.40
#
# مرحله 91:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 459.50 درجه سانتی‌گراد, نسبت فشار = -12.30
# امتیاز عملکرد (Reward): 370.06
#
# مرحله 92:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 464.00 درجه سانتی‌گراد, نسبت فشار = -12.60
# امتیاز عملکرد (Reward): 373.72
#
# مرحله 93:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 468.50 درجه سانتی‌گراد, نسبت فشار = -12.90
# امتیاز عملکرد (Reward): 377.38
#
# مرحله 94:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 473.00 درجه سانتی‌گراد, نسبت فشار = -13.20
# امتیاز عملکرد (Reward): 381.04
#
# مرحله 95:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 477.50 درجه سانتی‌گراد, نسبت فشار = -13.50
# امتیاز عملکرد (Reward): 384.70
#
# مرحله 96:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 482.00 درجه سانتی‌گراد, نسبت فشار = -13.80
# امتیاز عملکرد (Reward): 388.36
#
# مرحله 97:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 486.50 درجه سانتی‌گراد, نسبت فشار = -14.10
# امتیاز عملکرد (Reward): 392.02
#
# مرحله 98:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 491.00 درجه سانتی‌گراد, نسبت فشار = -14.40
# امتیاز عملکرد (Reward): 395.68
#
# مرحله 99:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 495.50 درجه سانتی‌گراد, نسبت فشار = -14.70
# امتیاز عملکرد (Reward): 399.34
#
# مرحله 100:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00 درجه, نرخ جریان هوا = 50.00 کیلوگرم بر ثانیه
# وضعیت فعلی: دما = 500.00 درجه سانتی‌گراد, نسبت فشار = -15.00
# امتیاز عملکرد (Reward): 403.00

# %% [markdown]
# ### **۱. زاویه‌ی پره‌ها (Blade Angle)**
# - **توضیح:**
#   زاویه‌ی پره‌های کمپرسور نقش مهمی در جریان هوا و فشار تولیدی دارد. تنظیم نادرست این زاویه می‌تواند باعث کاهش راندمان و افزایش تلفات انرژی شود.
# - **هدف بهینه‌سازی:**
#   - ماکزیمم کردن راندمان جریان هوا
#   - کاهش افت فشار (Pressure Drop)
#   - جلوگیری از پدیده‌ی **Surge** (جریان معکوس ناخواسته)
#
# ---
#
# ### **۲. نرخ جریان هوا (Airflow Rate)**
# - **توضیح:**
#   نرخ جریان هوا به مقدار هوایی اشاره دارد که کمپرسور در واحد زمان به داخل سیستم می‌کشد. این پارامتر مستقیماً بر عملکرد توربین و تولید انرژی تأثیر می‌گذارد.
# - **هدف بهینه‌سازی:**
#   - حفظ تعادل بین نرخ جریان هوا و نسبت فشار
#   - کاهش مصرف انرژی برای کشیدن هوا
#   - جلوگیری از شرایط **Choking** (جریان بیش از حد)
#
# ---
#
# ### **۳. نسبت فشار (Pressure Ratio)**
# - **توضیح:**
#   نسبت فشار نسبت بین فشار خروجی و فشار ورودی کمپرسور است. این پارامتر یکی از مهم‌ترین عوامل تعیین‌کننده‌ی راندمان کلی سیستم است.
# - **هدف بهینه‌سازی:**
#   - افزایش نسبت فشار بدون افزایش مصرف انرژی
#   - کاهش تنش‌های حرارتی و مکانیکی روی پره‌ها
#   - جلوگیری از شرایط **Surge** و **Stall**
#
# ---
#
# ### **۴. دمای ورودی هوا (Inlet Air Temperature)**
# - **توضیح:**
#   دمای هوا در ورودی کمپرسور تأثیر مستقیمی بر چگالی هوا و در نتیجه جریان جرمی هوا دارد. دمای بالاتر باعث کاهش چگالی و کاهش راندمان می‌شود.
# - **هدف بهینه‌سازی:**
#   - کاهش دمای ورودی هوا (به عنوان مثال با استفاده از سیستم‌های خنک‌کننده)
#   - بهبود راندمان ترمودینامیکی
#
# ---
#
# ### **۵. دمای توربین (Turbine Inlet Temperature - TIT)**
# - **توضیح:**
#   دمای ورودی به توربین (که از کمپرسور تأمین می‌شود) یکی از پارامترهای حساس است که بر راندمان و طول عمر توربین تأثیر می‌گذارد.
# - **هدف بهینه‌سازی:**
#   - افزایش دمای ورودی به توربین برای افزایش راندمان (در حد تحمل مواد)
#   - جلوگیری از آسیب حرارتی به پره‌ها
#
# ---
#
# ### **۶. سرعت چرخش (Rotational Speed - RPM)**
# - **توضیح:**
#   سرعت چرخش کمپرسور و توربین بر عملکرد کلی سیستم تأثیر می‌گذارد. سرعت بیش از حد یا کمتر از حد می‌تواند باعث کاهش راندمان یا حتی آسیب به تجهیزات شود.
# - **هدف بهینه‌سازی:**
#   - تنظیم سرعت بهینه برای حداکثر راندمان
#   - جلوگیری از لرزش‌های مکانیکی و ارتعاشات
#
# ---
#
# ### **۷. بازدهی ایزنتروپیک (Isentropic Efficiency)**
# - **توضیح:**
#   بازدهی ایزنتروپیک نشان‌دهنده‌ی میزان راندمان ترمودینامیکی کمپرسور است. این پارامتر نشان می‌دهد که چقدر کمپرسور به صورت ایده‌آل کار می‌کند.
# - **هدف بهینه‌سازی:**
#   - افزایش بازدهی ایزنتروپیک
#   - کاهش تلفات انرژی در فرآیند فشرده‌سازی
#
# ---
#
# ### **۸. مصرف سوخت (Fuel Consumption)**
# - **توضیح:**
#   مصرف سوخت یکی از مهم‌ترین پارامترهای اقتصادی و زیست‌محیطی است. کاهش مصرف سوخت بدون کاهش توان خروجی، هدف اصلی بهینه‌سازی است.
# - **هدف بهینه‌سازی:**
#   - کاهش مصرف سوخت
#   - افزایش توان خروجی نسبت به مصرف سوخت
#
# ---
#
# ### **۹. شرایط محیطی (Ambient Conditions)**
# - **توضیح:**
#   شرایط محیطی مانند دما، فشار و رطوبت هوا در محل نصب توربین تأثیر زیادی بر عملکرد کمپرسور دارد.
# - **هدف بهینه‌سازی:**
#   - تنظیم پارامترهای کمپرسور برای شرایط محیطی خاص
#   - استفاده از سیستم‌های خنک‌کننده یا فیلترهای هوای مناسب
#
# ---
#
# ### **۱۰. پدیده‌های ناپایداری (Surge و Stall)**
# - **توضیح:**
#   **Surge** و **Stall** دو پدیده‌ی ناپایداری هستند که می‌توانند باعث آسیب به کمپرسور شوند. Surge زمانی رخ می‌دهد که جریان هوا به طور ناگهانی معکوس شود، و Stall زمانی رخ می‌دهد که جریان هوا در بخشی از کمپرسور متوقف شود.
# - **هدف بهینه‌سازی:**
#   - جلوگیری از وقوع Surge و Stall
#   - تنظیم پارامترهای کمپرسور برای کار در محدوده‌ی پایدار
#
# ---
#
# ### **جمع‌بندی:**
# برای بهینه‌سازی کمپرسور **SGT-400**، پارامترهای زیر را می‌توان به عنوان اولویت‌های اصلی در نظر گرفت:
# 1. **زاویه‌ی پره‌ها (Blade Angle)**
# 2. **نرخ جریان هوا (Airflow Rate)**
# 3. **نسبت فشار (Pressure Ratio)**
# 4. **دمای ورودی هوا (Inlet Air Temperature)**
# 5. **سرعت چرخش (RPM)**

# %%
import random

# پارامترهای قابل تنظیم
parameters = {
    "blade_angle": (10, 30),  # زاویه‌ی پره‌ها (Blade Angle) - محدوده: 10 تا 30 درجه
    "airflow_rate": (50, 150),  # نرخ جریان هوا (Airflow Rate) - محدوده: 50 تا 150 کیلوگرم بر ثانیه
    "pressure_ratio": (10, 20),  # نسبت فشار (Pressure Ratio) - محدوده: 10 تا 20
    "inlet_temperature": (20, 60),  # دمای ورودی هوا (Inlet Air Temperature) - محدوده: 20 تا 60 درجه سانتی‌گراد
    "rpm": (3000, 6000)  # سرعت چرخش (RPM) - محدوده: 3000 تا 6000 دور بر دقیقه
}

# تابع برازندگی (Fitness Function)
def fitness(solution):
    blade_angle, airflow_rate, pressure_ratio, inlet_temperature, rpm = solution
    # شبیه‌سازی راندمان کلی (مثال ساده‌شده)
    efficiency = (
        0.8 * blade_angle
        + 0.5 * airflow_rate
        - 0.2 * pressure_ratio
        + 0.3 * inlet_temperature
        + 0.1 * rpm
        - 0.01 * abs(blade_angle - 25)  # جریمه برای انحراف از زاویه‌ی بهینه
    )
    return efficiency

# مقداردهی اولیه جمعیت
def initialize_population(size):
    population = []
    for _ in range(size):
        individual = [
            random.uniform(parameters["blade_angle"][0], parameters["blade_angle"][1]),
            random.uniform(parameters["airflow_rate"][0], parameters["airflow_rate"][1]),
            random.uniform(parameters["pressure_ratio"][0], parameters["pressure_ratio"][1]),
            random.uniform(parameters["inlet_temperature"][0], parameters["inlet_temperature"][1]),
            random.uniform(parameters["rpm"][0], parameters["rpm"][1])
        ]
        population.append(individual)
    return population

# انتخاب والدین
def select_parents(population, fitness_scores, num_parents):
    parents = [population[i] for i in sorted(range(len(fitness_scores)), key=lambda x: fitness_scores[x], reverse=True)[:num_parents]]
    return parents

# ترکیب (Crossover)
def crossover(parent1, parent2):
    crossover_point = random.randint(1, len(parent1) - 1)
    child1 = parent1[:crossover_point] + parent2[crossover_point:]
    child2 = parent2[:crossover_point] + parent1[crossover_point:]
    return child1, child2

# جهش (Mutation)
def mutate(individual, mutation_rate=0.1):
    for i in range(len(individual)):
        if random.random() < mutation_rate:
            individual[i] += random.uniform(-1, 1)  # تغییر کوچک
            # محدود کردن مقادیر به محدوده‌ی مجاز
            individual[i] = max(parameters[list(parameters.keys())[i]][0], min(individual[i], parameters[list(parameters.keys())[i]][1]))
    return individual

# الگوریتم ژنتیک اصلی
def genetic_algorithm(pop_size, generations):
    population = initialize_population(pop_size)
    for generation in range(generations):
        fitness_scores = [fitness(individual) for individual in population]
        parents = select_parents(population, fitness_scores, pop_size // 2)
        next_generation = []
        for i in range(0, len(parents), 2):
            child1, child2 = crossover(parents[i], parents[i + 1])
            next_generation.append(mutate(child1))
            next_generation.append(mutate(child2))
        population = next_generation
        print(f"نسل {generation + 1}: بهترین برازندگی = {max(fitness_scores)}")
    best_solution = population[fitness_scores.index(max(fitness_scores))]
    return best_solution

# اجرای الگوریتم
best_params = genetic_algorithm(pop_size=20, generations=50)
print("پارامترهای بهینه:", best_params)
# Out:
# نسل 1: بهترین برازندگی = 663.0992413900038
# نسل 2: بهترین برازندگی = 677.1982237943209
# نسل 3: بهترین برازندگی = 667.034389729518
# نسل 4: بهترین برازندگی = 677.2358170175671
# نسل 5: بهترین برازندگی = 683.1921757367655
# نسل 6: بهترین برازندگی = 681.8225622193038
# نسل 7: بهترین برازندگی = 684.0909898101287
# نسل 8: بهترین برازندگی = 682.5300110623167
# نسل 9: بهترین برازندگی = 684.7405113394102
# نسل 10: بهترین برازندگی = 680.6597033184613
# نسل 11: بهترین برازندگی = 685.4713808299061
# نسل 12: بهترین برازندگی = 682.679127811402
# نسل 13: بهترین برازندگی = 683.7547902533519
# نسل 14: بهترین برازندگی = 682.7751275228286
# نسل 15: بهترین برازندگی = 683.8507899647783
# نسل 16: بهترین برازندگی = 682.7751275228286
# نسل 17: بهترین برازندگی = 684.5621242575129
# نسل 18: بهترین برازندگی = 681.0672891453556
# نسل 19: بهترین برازندگی = 686.1739629235594
# نسل 20: بهترین برازندگی = 683.4369684607507
# نسل 21: بهترین برازندگی = 686.1739629235594
# نسل 22: بهترین برازندگی = 678.1937170053749
# نسل 23: بهترین برازندگی = 686.1739629235594
# نسل 24: بهترین برازندگی = 688.22359780293
# نسل 25: بهترین برازندگی = 684.5670448971985
# نسل 26: بهترین برازندگی = 687.8935787341919
# نسل 27: بهترین برازندگی = 685.3603986254072
# نسل 28: بهترین برازندگی = 685.9928436001578
# نسل 29: بهترین برازندگی = 692.492791643137
# نسل 30: بهترین برازندگی = 692.7190897500919
# نسل 31: بهترین برازندگی = 690.4748061092948
# نسل 32: بهترین برازندگی = 694.407056215196
# نسل 33: بهترین برازندگی = 692.162772574399
# نسل 34: بهترین برازندگی = 693.1740191799465
# نسل 35: بهترین برازندگی = 692.1371183660968
# نسل 36: بهترین برازندگی = 693.1740191799465
# نسل 37: بهترین برازندگی = 690.9297355391495
# نسل 38: بهترین برازندگی = 694.711421075632
# نسل 39: بهترین برازندگی = 683.8079877610318
# نسل 40: بهترین برازندگی = 687.8952501885674
# نسل 41: بهترین برازندگی = 684.0880243848756
# نسل 42: بهترین برازندگی = 694.1378677005256
# نسل 43: بهترین برازندگی = 684.8358594235127
# نسل 44: بهترین برازندگی = 694.159005376853
# نسل 45: بهترین برازندگی = 691.6827815388468
# نسل 46: بهترین برازندگی = 694.159005376853
# نسل 47: بهترین برازندگی = 690.8342853992216
# نسل 48: بهترین برازندگی = 693.9207831483859
# نسل 49: بهترین برازندگی = 691.5347415948727
# نسل 50: بهترین برازندگی = 686.660699767134
# پارامترهای بهینه: [26.14492136016582, 145.97700502247434, 12.652018936811947, 36.791615264186966, 5819.789284352337]

# %%
import numpy as np
import gym
from gym import spaces
from stable_baselines3 import PPO

# محیط سفارشی برای کمپرسور SGT-400
class CompressorEnv(gym.Env):
    def __init__(self):
        super(CompressorEnv, self).__init__()
        # تعریف فضای عملیات و مشاهدات
        self.action_space = spaces.Box(
            low=np.array([10, 50, 10, 20, 3000]),  # حداقل مقادیر: زاویه‌ی پره، نرخ جریان هوا، نسبت فشار، دما، RPM
            high=np.array([30, 150, 20, 60, 6000]),  # حداکثر مقادیر
            dtype=np.float32
        )
        self.observation_space = spaces.Box(
            low=np.array([0, 0, 0, 0, 0]),  # حداقل مقادیر مشاهدات
            high=np.array([100, 20, 100, 100, 7000]),  # حداکثر مقادیر
            dtype=np.float32
        )
        # حالت اولیه
        self.state = np.array([50, 15, 40, 30, 4000])  # دما، نسبت فشار، RPM، ورودی‌های اولیه
        self.steps = 0

    def step(self, action):
        blade_angle, airflow_rate, pressure_ratio, inlet_temperature, rpm = action
        temperature, current_pressure_ratio, current_rpm, _, _ = self.state
        # شبیه‌سازی دینامیک کمپرسور
        new_temperature = temperature + 0.1 * airflow_rate - 0.05 * blade_angle
        new_pressure_ratio = current_pressure_ratio + 0.02 * blade_angle - 0.01 * airflow_rate
        new_rpm = current_rpm + 10 * (rpm - current_rpm) / 1000
        # به‌روزرسانی حالت
        self.state = np.array([new_temperature, new_pressure_ratio, new_rpm, inlet_temperature, rpm])
        # محاسبه پاداش
        reward = 0.8 * new_temperature - 0.2 * new_pressure_ratio + 0.1 * rpm
        # بررسی پایان دوره
        self.steps += 1
        done = self.steps >= 100  # دوره پس از ۱۰۰ مرحله به پایان می‌رسد
        return self.state, reward, done, {}

    def reset(self):
        self.state = np.array([50, 15, 40, 30, 4000])  # بازنشانی به حالت اولیه
        self.steps = 0
        return self.state

# ایجاد محیط
env = CompressorEnv()

# آموزش عامل PPO
print("آموزش عامل PPO شروع شد...")
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)
print("آموزش عامل PPO به پایان رسید.")

# تست عامل آموزش‌دیده
obs = env.reset()
for step in range(100):
    action, _states = model.predict(obs)
    obs, reward, done, info = env.step(action)
    print(f"مرحله {step + 1}:")
    print(f"عملیات انجام‌شده: زاویه‌ی پره = {action[0]:.2f}, نرخ جریان هوا = {action[1]:.2f}, نسبت فشار = {action[2]:.2f}, دمای ورودی = {action[3]:.2f}, RPM = {action[4]:.2f}")
    print(f"وضعیت فعلی: دما = {obs[0]:.2f}, نسبت فشار = {obs[1]:.2f}, RPM = {obs[2]:.2f}, دمای ورودی = {obs[3]:.2f}")
    print(f"امتیاز عملکرد (Reward): {reward:.2f}\n")
    if done:
        obs = env.reset()
# Out:
# آموزش عامل PPO شروع شد...
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | 5.22e+04 |
# | time/              |          |
# |    fps             | 1556     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.22e+04     |
# | time/                   |              |
# |    fps                  | 1061         |
# |    iterations           | 2            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0025669555 |
# |    clip_fraction        | 0.00151      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 4.49e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.22e+07     |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.0021      |
# |    std                  | 1            |
# |    value_loss           | 6.19e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.22e+04     |
# | time/                   |              |
# |    fps                  | 964          |
# |    iterations           | 3            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0012473777 |
# |    clip_fraction        | 4.88e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 3.28e-06     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.2e+07      |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00118     |
# |    std                  | 0.999        |
# |    value_loss           | 6.25e+07     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 100          |
# |    ep_rew_mean          | 5.22e+04     |
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 4            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0021646419 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -7.09        |
# |    explained_variance   | 8.34e-07     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.09e+07     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00168     |
# |    std                  | 0.998        |
# |    value_loss           | 6.17e+07     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | 5.22e+04    |
# | time/                   |             |
# |    fps                  | 808         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.001829744 |
# |    clip_fraction        | 0.000342    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.09       |
# |    explained_variance   | 3.58e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.12e+07    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00127    |
# |    std                  | 0.999       |
# |    value_loss           | 6.24e+07    |
# -----------------------------------------
# آموزش عامل PPO به پایان رسید.
# مرحله 1:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 54.50, نسبت فشار = 14.70, RPM = 69.60, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 340.66
#
# مرحله 2:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 59.00, نسبت فشار = 14.40, RPM = 98.90, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 344.32
#
# مرحله 3:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 63.50, نسبت فشار = 14.10, RPM = 127.91, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 347.98
#
# مرحله 4:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 68.00, نسبت فشار = 13.80, RPM = 156.64, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 351.64
#
# مرحله 5:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 72.50, نسبت فشار = 13.50, RPM = 185.07, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 355.30
#
# مرحله 6:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 77.00, نسبت فشار = 13.20, RPM = 213.22, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 358.96
#
# مرحله 7:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 81.50, نسبت فشار = 12.90, RPM = 241.09, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 362.62
#
# مرحله 8:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 86.00, نسبت فشار = 12.60, RPM = 268.68, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 366.28
#
# مرحله 9:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 90.50, نسبت فشار = 12.30, RPM = 295.99, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 369.94
#
# مرحله 10:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 95.00, نسبت فشار = 12.00, RPM = 323.03, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 373.60
#
# مرحله 11:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 99.50, نسبت فشار = 11.70, RPM = 349.80, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 377.26
#
# مرحله 12:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 104.00, نسبت فشار = 11.40, RPM = 376.30, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 380.92
#
# مرحله 13:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 108.50, نسبت فشار = 11.10, RPM = 402.54, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 384.58
#
# مرحله 14:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 113.00, نسبت فشار = 10.80, RPM = 428.51, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 388.24
#
# مرحله 15:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 117.50, نسبت فشار = 10.50, RPM = 454.23, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 391.90
#
# مرحله 16:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 122.00, نسبت فشار = 10.20, RPM = 479.68, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 395.56
#
# مرحله 17:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 126.50, نسبت فشار = 9.90, RPM = 504.89, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 399.22
#
# مرحله 18:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 131.00, نسبت فشار = 9.60, RPM = 529.84, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 402.88
#
# مرحله 19:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 135.50, نسبت فشار = 9.30, RPM = 554.54, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 406.54
#
# مرحله 20:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 140.00, نسبت فشار = 9.00, RPM = 579.00, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 410.20
#
# مرحله 21:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 144.50, نسبت فشار = 8.70, RPM = 603.21, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 413.86
#
# مرحله 22:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 149.00, نسبت فشار = 8.40, RPM = 627.17, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 417.52
#
# مرحله 23:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 153.50, نسبت فشار = 8.10, RPM = 650.90, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 421.18
#
# مرحله 24:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 158.00, نسبت فشار = 7.80, RPM = 674.39, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 424.84
#
# مرحله 25:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 162.50, نسبت فشار = 7.50, RPM = 697.65, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 428.50
#
# مرحله 26:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 167.00, نسبت فشار = 7.20, RPM = 720.67, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 432.16
#
# مرحله 27:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 171.50, نسبت فشار = 6.90, RPM = 743.47, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 435.82
#
# مرحله 28:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 176.00, نسبت فشار = 6.60, RPM = 766.03, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 439.48
#
# مرحله 29:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 180.50, نسبت فشار = 6.30, RPM = 788.37, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 443.14
#
# مرحله 30:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 185.00, نسبت فشار = 6.00, RPM = 810.49, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 446.80
#
# مرحله 31:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 189.50, نسبت فشار = 5.70, RPM = 832.38, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 450.46
#
# مرحله 32:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 194.00, نسبت فشار = 5.40, RPM = 854.06, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 454.12
#
# مرحله 33:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 198.50, نسبت فشار = 5.10, RPM = 875.52, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 457.78
#
# مرحله 34:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 203.00, نسبت فشار = 4.80, RPM = 896.76, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 461.44
#
# مرحله 35:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 207.50, نسبت فشار = 4.50, RPM = 917.79, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 465.10
#
# مرحله 36:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 212.00, نسبت فشار = 4.20, RPM = 938.62, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 468.76
#
# مرحله 37:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 216.50, نسبت فشار = 3.90, RPM = 959.23, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 472.42
#
# مرحله 38:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 221.00, نسبت فشار = 3.60, RPM = 979.64, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 476.08
#
# مرحله 39:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 225.50, نسبت فشار = 3.30, RPM = 999.84, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 479.74
#
# مرحله 40:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 230.00, نسبت فشار = 3.00, RPM = 1019.84, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 483.40
#
# مرحله 41:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 234.50, نسبت فشار = 2.70, RPM = 1039.65, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 487.06
#
# مرحله 42:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 239.00, نسبت فشار = 2.40, RPM = 1059.25, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 490.72
#
# مرحله 43:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 243.50, نسبت فشار = 2.10, RPM = 1078.66, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 494.38
#
# مرحله 44:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 248.00, نسبت فشار = 1.80, RPM = 1097.87, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 498.04
#
# مرحله 45:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 252.50, نسبت فشار = 1.50, RPM = 1116.89, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 501.70
#
# مرحله 46:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 257.00, نسبت فشار = 1.20, RPM = 1135.72, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 505.36
#
# مرحله 47:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 261.50, نسبت فشار = 0.90, RPM = 1154.36, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 509.02
#
# مرحله 48:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 266.00, نسبت فشار = 0.60, RPM = 1172.82, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 512.68
#
# مرحله 49:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 270.50, نسبت فشار = 0.30, RPM = 1191.09, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 516.34
#
# مرحله 50:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 275.00, نسبت فشار = -0.00, RPM = 1209.18, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 520.00
#
# مرحله 51:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 279.50, نسبت فشار = -0.30, RPM = 1227.09, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 523.66
#
# مرحله 52:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 284.00, نسبت فشار = -0.60, RPM = 1244.82, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 527.32
#
# مرحله 53:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 288.50, نسبت فشار = -0.90, RPM = 1262.37, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 530.98
#
# مرحله 54:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 293.00, نسبت فشار = -1.20, RPM = 1279.75, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 534.64
#
# مرحله 55:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 297.50, نسبت فشار = -1.50, RPM = 1296.95, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 538.30
#
# مرحله 56:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 302.00, نسبت فشار = -1.80, RPM = 1313.98, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 541.96
#
# مرحله 57:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 306.50, نسبت فشار = -2.10, RPM = 1330.84, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 545.62
#
# مرحله 58:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 311.00, نسبت فشار = -2.40, RPM = 1347.53, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 549.28
#
# مرحله 59:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 315.50, نسبت فشار = -2.70, RPM = 1364.06, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 552.94
#
# مرحله 60:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 320.00, نسبت فشار = -3.00, RPM = 1380.42, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 556.60
#
# مرحله 61:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 324.50, نسبت فشار = -3.30, RPM = 1396.61, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 560.26
#
# مرحله 62:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 329.00, نسبت فشار = -3.60, RPM = 1412.65, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 563.92
#
# مرحله 63:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 333.50, نسبت فشار = -3.90, RPM = 1428.52, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 567.58
#
# مرحله 64:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 338.00, نسبت فشار = -4.20, RPM = 1444.23, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 571.24
#
# مرحله 65:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 342.50, نسبت فشار = -4.50, RPM = 1459.79, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 574.90
#
# مرحله 66:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 347.00, نسبت فشار = -4.80, RPM = 1475.19, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 578.56
#
# مرحله 67:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 351.50, نسبت فشار = -5.10, RPM = 1490.44, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 582.22
#
# مرحله 68:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 356.00, نسبت فشار = -5.40, RPM = 1505.54, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 585.88
#
# مرحله 69:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 360.50, نسبت فشار = -5.70, RPM = 1520.48, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 589.54
#
# مرحله 70:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 365.00, نسبت فشار = -6.00, RPM = 1535.28, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 593.20
#
# مرحله 71:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 369.50, نسبت فشار = -6.30, RPM = 1549.92, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 596.86
#
# مرحله 72:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 374.00, نسبت فشار = -6.60, RPM = 1564.43, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 600.52
#
# مرحله 73:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 378.50, نسبت فشار = -6.90, RPM = 1578.78, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 604.18
#
# مرحله 74:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 383.00, نسبت فشار = -7.20, RPM = 1592.99, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 607.84
#
# مرحله 75:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 387.50, نسبت فشار = -7.50, RPM = 1607.06, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 611.50
#
# مرحله 76:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 392.00, نسبت فشار = -7.80, RPM = 1620.99, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 615.16
#
# مرحله 77:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 396.50, نسبت فشار = -8.10, RPM = 1634.78, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 618.82
#
# مرحله 78:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 401.00, نسبت فشار = -8.40, RPM = 1648.44, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 622.48
#
# مرحله 79:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 405.50, نسبت فشار = -8.70, RPM = 1661.95, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 626.14
#
# مرحله 80:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 410.00, نسبت فشار = -9.00, RPM = 1675.33, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 629.80
#
# مرحله 81:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 414.50, نسبت فشار = -9.30, RPM = 1688.58, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 633.46
#
# مرحله 82:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 419.00, نسبت فشار = -9.60, RPM = 1701.69, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 637.12
#
# مرحله 83:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 423.50, نسبت فشار = -9.90, RPM = 1714.68, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 640.78
#
# مرحله 84:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 428.00, نسبت فشار = -10.20, RPM = 1727.53, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 644.44
#
# مرحله 85:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 432.50, نسبت فشار = -10.50, RPM = 1740.25, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 648.10
#
# مرحله 86:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 437.00, نسبت فشار = -10.80, RPM = 1752.85, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 651.76
#
# مرحله 87:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 441.50, نسبت فشار = -11.10, RPM = 1765.32, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 655.42
#
# مرحله 88:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 446.00, نسبت فشار = -11.40, RPM = 1777.67, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 659.08
#
# مرحله 89:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 450.50, نسبت فشار = -11.70, RPM = 1789.89, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 662.74
#
# مرحله 90:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 455.00, نسبت فشار = -12.00, RPM = 1801.99, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 666.40
#
# مرحله 91:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 459.50, نسبت فشار = -12.30, RPM = 1813.97, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 670.06
#
# مرحله 92:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 464.00, نسبت فشار = -12.60, RPM = 1825.83, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 673.72
#
# مرحله 93:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 468.50, نسبت فشار = -12.90, RPM = 1837.58, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 677.38
#
# مرحله 94:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 473.00, نسبت فشار = -13.20, RPM = 1849.20, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 681.04
#
# مرحله 95:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 477.50, نسبت فشار = -13.50, RPM = 1860.71, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 684.70
#
# مرحله 96:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 482.00, نسبت فشار = -13.80, RPM = 1872.10, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 688.36
#
# مرحله 97:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 486.50, نسبت فشار = -14.10, RPM = 1883.38, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 692.02
#
# مرحله 98:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 491.00, نسبت فشار = -14.40, RPM = 1894.55, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 695.68
#
# مرحله 99:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 495.50, نسبت فشار = -14.70, RPM = 1905.60, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 699.34
#
# مرحله 100:
# عملیات انجام‌شده: زاویه‌ی پره = 10.00, نرخ جریان هوا = 50.00, نسبت فشار = 10.00, دمای ورودی = 20.00, RPM = 3000.00
# وضعیت فعلی: دما = 500.00, نسبت فشار = -15.00, RPM = 1916.54, دمای ورودی = 20.00
# امتیاز عملکرد (Reward): 703.00

# %% [markdown]
# در ادامه، دو مدل **الگوریتم ژنتیک (Genetic Algorithm)** و **یادگیری تقویتی (Reinforcement Learning)** برای بهینه‌سازی پارامترهای کمپرسور SGT-400 شامل **زاویه‌ی پره‌ها (Blade Angle)**، **نرخ جریان هوا (Airflow Rate)**، **نسبت فشار (Pressure Ratio)**، **دمای ورودی هوا (Inlet Air Temperature)** و **سرعت چرخش (RPM)** ارائه شده است.
#
# ---
#
# ### **۱. مدل الگوریتم ژنتیک (Genetic Algorithm)**
#
# #### **کد پیاده‌سازی:**
# ```python
# import random
#
# # پارامترهای قابل تنظیم
# parameters = {
#     "blade_angle": (10, 30),  # زاویه‌ی پره‌ها (Blade Angle) - محدوده: 10 تا 30 درجه
#     "airflow_rate": (50, 150),  # نرخ جریان هوا (Airflow Rate) - محدوده: 50 تا 150 کیلوگرم بر ثانیه
#     "pressure_ratio": (10, 20),  # نسبت فشار (Pressure Ratio) - محدوده: 10 تا 20
#     "inlet_temperature": (20, 60),  # دمای ورودی هوا (Inlet Air Temperature) - محدوده: 20 تا 60 درجه سانتی‌گراد
#     "rpm": (3000, 6000)  # سرعت چرخش (RPM) - محدوده: 3000 تا 6000 دور بر دقیقه
# }
#
# # تابع برازندگی (Fitness Function)
# def fitness(solution):
#     blade_angle, airflow_rate, pressure_ratio, inlet_temperature, rpm = solution
#     # شبیه‌سازی راندمان کلی (مثال ساده‌شده)
#     efficiency = (
#         0.8 * blade_angle
#         + 0.5 * airflow_rate
#         - 0.2 * pressure_ratio
#         + 0.3 * inlet_temperature
#         + 0.1 * rpm
#         - 0.01 * abs(blade_angle - 25)  # جریمه برای انحراف از زاویه‌ی بهینه
#     )
#     return efficiency
#
# # مقداردهی اولیه جمعیت
# def initialize_population(size):
#     population = []
#     for _ in range(size):
#         individual = [
#             random.uniform(parameters["blade_angle"][0], parameters["blade_angle"][1]),
#             random.uniform(parameters["airflow_rate"][0], parameters["airflow_rate"][1]),
#             random.uniform(parameters["pressure_ratio"][0], parameters["pressure_ratio"][1]),
#             random.uniform(parameters["inlet_temperature"][0], parameters["inlet_temperature"][1]),
#             random.uniform(parameters["rpm"][0], parameters["rpm"][1])
#         ]
#         population.append(individual)
#     return population
#
# # انتخاب والدین
# def select_parents(population, fitness_scores, num_parents):
#     parents = [population[i] for i in sorted(range(len(fitness_scores)), key=lambda x: fitness_scores[x], reverse=True)[:num_parents]]
#     return parents
#
# # ترکیب (Crossover)
# def crossover(parent1, parent2):
#     crossover_point = random.randint(1, len(parent1) - 1)
#     child1 = parent1[:crossover_point] + parent2[crossover_point:]
#     child2 = parent2[:crossover_point] + parent1[crossover_point:]
#     return child1, child2
#
# # جهش (Mutation)
# def mutate(individual, mutation_rate=0.1):
#     for i in range(len(individual)):
#         if random.random() < mutation_rate:
#             individual[i] += random.uniform(-1, 1)  # تغییر کوچک
#             # محدود کردن مقادیر به محدوده‌ی مجاز
#             individual[i] = max(parameters[list(parameters.keys())[i]][0], min(individual[i], parameters[list(parameters.keys())[i]][1]))
#     return individual
#
# # الگوریتم ژنتیک اصلی
# def genetic_algorithm(pop_size, generations):
#     population = initialize_population(pop_size)
#     for generation in range(generations):
#         fitness_scores = [fitness(individual) for individual in population]
#         parents = select_parents(population, fitness_scores, pop_size // 2)
#         next_generation = []
#         for i in range(0, len(parents), 2):
#             child1, child2 = crossover(parents[i], parents[i + 1])
#             next_generation.append(mutate(child1))
#             next_generation.append(mutate(child2))
#         population = next_generation
#         print(f"نسل {generation + 1}: بهترین برازندگی = {max(fitness_scores)}")
#     best_solution = population[fitness_scores.index(max(fitness_scores))]
#     return best_solution
#
# # اجرای الگوریتم
# best_params = genetic_algorithm(pop_size=20, generations=50)
# print("پارامترهای بهینه:", best_params)
# ```
#
#
# - **هدف:**
#   این الگوریتم پارامترهای کلیدی کمپرسور را بهینه می‌کند تا راندمان بالا و مصرف انرژی کمتری داشته باشد.
# - **مراحل:**
#   1. **مقداردهی اولیه:** جمعیت اولیه‌ای از راه‌حل‌ها (پارامترها) تولید می‌شود.
#   2. **برازندگی:** هر راه‌حل بر اساس یک تابع برازندگی (مانند راندمان) ارزیابی می‌شود.
#   3. **انتخاب:** بهترین راه‌حل‌ها برای تولید نسل بعدی انتخاب می‌شوند.
#   4. **ترکیب و جهش:** راه‌حل‌های جدید با ترکیب و تغییر تصادفی ایجاد می‌شوند.
#   5. **تکرار:** این فرآیند تا رسیدن به پارامترهای بهینه ادامه می‌یابد.
# - **خروجی:**
#   پارامترهای بهینه‌ی کمپرسور (مثل زاویه‌ی پره، نرخ جریان هوا و غیره) نمایش داده می‌شوند.
#
# ---
#
# ### **۲. مدل یادگیری تقویتی (Reinforcement Learning)**
#
# #### **کد پیاده‌سازی:**
# ```python
# import numpy as np
# import gym
# from gym import spaces
# from stable_baselines3 import PPO
#
# # محیط سفارشی برای کمپرسور SGT-400
# class CompressorEnv(gym.Env):
#     def __init__(self):
#         super(CompressorEnv, self).__init__()
#         # تعریف فضای عملیات و مشاهدات
#         self.action_space = spaces.Box(
#             low=np.array([10, 50, 10, 20, 3000]),  # حداقل مقادیر: زاویه‌ی پره، نرخ جریان هوا، نسبت فشار، دما، RPM
#             high=np.array([30, 150, 20, 60, 6000]),  # حداکثر مقادیر
#             dtype=np.float32
#         )
#         self.observation_space = spaces.Box(
#             low=np.array([0, 0, 0, 0, 0]),  # حداقل مقادیر مشاهدات
#             high=np.array([100, 20, 100, 100, 7000]),  # حداکثر مقادیر
#             dtype=np.float32
#         )
#         # حالت اولیه
#         self.state = np.array([50, 15, 40, 30, 4000])  # دما، نسبت فشار، RPM، ورودی‌های اولیه
#         self.steps = 0
#
#     def step(self, action):
#         blade_angle, airflow_rate, pressure_ratio, inlet_temperature, rpm = action
#         temperature, current_pressure_ratio, current_rpm, _, _ = self.state
#         # شبیه‌سازی دینامیک کمپرسور
#         new_temperature = temperature + 0.1 * airflow_rate - 0.05 * blade_angle
#         new_pressure_ratio = current_pressure_ratio + 0.02 * blade_angle - 0.01 * airflow_rate
#         new_rpm = current_rpm + 10 * (rpm - current_rpm) / 1000
#         # به‌روزرسانی حالت
#         self.state = np.array([new_temperature, new_pressure_ratio, new_rpm, inlet_temperature, rpm])
#         # محاسبه پاداش
#         reward = 0.8 * new_temperature - 0.2 * new_pressure_ratio + 0.1 * rpm
#         # بررسی پایان دوره
#         self.steps += 1
#         done = self.steps >= 100  # دوره پس از ۱۰۰ مرحله به پایان می‌رسد
#         return self.state, reward, done, {}
#
#     def reset(self):
#         self.state = np.array([50, 15, 40, 30, 4000])  # بازنشانی به حالت اولیه
#         self.steps = 0
#         return self.state
#
# # ایجاد محیط
# env = CompressorEnv()
#
# # آموزش عامل PPO
# print("آموزش عامل PPO شروع شد...")
# model = PPO("MlpPolicy", env, verbose=1)
# model.learn(total_timesteps=10000)
# print("آموزش عامل PPO به پایان رسید.")
#
# # تست عامل آموزش‌دیده
# obs = env.reset()
# for step in range(100):
#     action, _states = model.predict(obs)
#     obs, reward, done, info = env.step(action)
#     print(f"مرحله {step + 1}:")
#     print(f"عملیات انجام‌شده: زاویه‌ی پره = {action[0]:.2f}, نرخ جریان هوا = {action[1]:.2f}, نسبت فشار = {action[2]:.2f}, دمای ورودی = {action[3]:.2f}, RPM = {action[4]:.2f}")
#     print(f"وضعیت فعلی: دما = {obs[0]:.2f}, نسبت فشار = {obs[1]:.2f}, RPM = {obs[2]:.2f}, دمای ورودی = {obs[3]:.2f}")
#     print(f"امتیاز عملکرد (Reward): {reward:.2f}\n")
#     if done:
#         obs = env.reset()
# ```
#
# #### **توضیحات به زبان فارسی:**
# - **هدف:**
#   این مدل یک عامل (Agent) را آموزش می‌دهد تا پارامترهای کمپرسور را به صورت بلادرنگ تنظیم کند و بهترین عملکرد را از سیستم بگیرد.
# - **مراحل:**
#   1. **محیط:** محیط شبیه‌سازی‌شده شامل پارامترهای کلیدی کمپرسور است.
#   2. **عامل:** عامل تصمیم می‌گیرد که چه عملیاتی (مثل تنظیم زاویه‌ی پره یا نرخ جریان هوا) انجام دهد.
#   3. **پاداش:** عامل بر اساس عملکرد خود (مثل راندمان یا کاهش مصرف انرژی) پاداش دریافت می‌کند.
#   4. **یادگیری:** عامل با تجربه‌ی عملیات‌ها و دریافت پاداش، بهترین استراتژی را یاد می‌گیرد.
# - **خروجی:**
#   در هر مرحله، عملیات انجام‌شده، وضعیت فعلی و امتیاز عملکرد نمایش داده می‌شود.
#
# ---
#
# ### **مقایسه دو مدل:**
#
# | ویژگی                  | الگوریتم ژنتیک (GA)                          | یادگیری تقویتی (RL)                     |
# |------------------------|---------------------------------------------|-----------------------------------------|
# | **نوع**               | جستجوی تکاملی                              | یادگیری ماشین                           |
# | **استفاده**           | بهینه‌سازی پارامترها در محیط‌های استاتیک   | کنترل بلادرنگ در محیط‌های پویا          |
# | **سرعت**              | کندتر (به دلیل تکرار نسل‌ها)              | سریع‌تر (یادگیری آنلاین)                |
# | **پیچیدگی**           | ساده‌تر برای پیاده‌سازی                    | نیاز به منابع محاسباتی بیشتر            |
# | **بهترین برای**       | یک‌بار بهینه‌سازی                         | تنظیم پیوسته و بلادرنگ                  |
#
# ---
#
# ### **جمع‌بندی:**
# - **الگوریتم ژنتیک:** برای یافتن پارامترهای بهینه‌ی ثابت کمپرسور مناسب است.
# - **یادگیری تقویتی:** برای کنترل بلادرنگ و تنظیم پارامترها در شرایط متغیر مناسب است.

# %% [markdown]
# ### **دو مدل برای اجرای بهینه‌سازی در LabVIEW**
#
# در ادامه، دو مدل برای بهینه‌سازی پارامترهای کمپرسور SGT-400 طراحی شده‌اند که می‌توانند در محیط **LabVIEW** پیاده‌سازی و اجرا شوند. این مدل‌ها شامل **الگوریتم ژنتیک (Genetic Algorithm)** و **یادگیری تقویتی (Reinforcement Learning)** هستند.
#
# ---
#
# ### **۱. مدل الگوریتم ژنتیک (Genetic Algorithm) در LabVIEW**
#
# #### **مراحل پیاده‌سازی:**
# 1. **ورودی‌ها:**
#    - **پارامترهای قابل تنظیم:**
#      - زاویه‌ی پره‌ها (Blade Angle)
#      - نرخ جریان هوا (Airflow Rate)
#      - نسبت فشار (Pressure Ratio)
#      - دمای ورودی هوا (Inlet Air Temperature)
#      - سرعت چرخش (RPM)
#    - **محدوده‌ی مقادیر:**
#      هر پارامتر دارای یک محدوده‌ی مشخص است که در LabVIEW به صورت اسلایدر یا ورودی عددی تنظیم می‌شود.
#
# 2. **تابع برازندگی (Fitness Function):**
#    - این تابع برای ارزیابی هر راه‌حل (مجموعه‌ای از پارامترها) استفاده می‌شود.
#    - مثال:
#      ```plaintext
#      Efficiency = 0.8 * Blade_Angle + 0.5 * Airflow_Rate - 0.2 * Pressure_Ratio + 0.3 * Inlet_Temperature + 0.1 * RPM
#      ```
#
# 3. **مراحل الگوریتم:**
#    - **مقداردهی اولیه:**
#      یک جمعیت اولیه از راه‌حل‌ها (پارامترها) تصادفی تولید می‌شود.
#    - **انتخاب والدین:**
#      بهترین راه‌حل‌ها بر اساس تابع برازندگی انتخاب می‌شوند.
#    - **ترکیب (Crossover):**
#      دو والد با هم ترکیب می‌شوند تا فرزندان جدید ایجاد شوند.
#    - **جهش (Mutation):**
#      تغییرات کوچکی به صورت تصادفی به فرزندان اعمال می‌شود.
#    - **تکرار:**
#      این فرآیند تا رسیدن به پارامترهای بهینه ادامه می‌یابد.
#
# 4. **خروجی:**
#    - پارامترهای بهینه‌ی کمپرسور (مثل زاویه‌ی پره، نرخ جریان هوا و غیره) نمایش داده می‌شوند.
#
# #### **پیاده‌سازی در LabVIEW:**
# - **بلوک‌های LabVIEW:**
#   - **Random Number Generator:** برای تولید جمعیت اولیه.
#   - **Formula Node:** برای محاسبه‌ی تابع برازندگی.
#   - **For Loop:** برای اجرای تکرارهای الگوریتم.
#   - **Array Operations:** برای مدیریت جمعیت و انتخاب والدین.
#   - **Graph Indicator:** برای نمایش نتایج (مثل بهترین برازندگی در هر نسل).
#
# #### **توضیحات به زبان فارسی:**
# - **هدف:**
#   این مدل پارامترهای کلیدی کمپرسور را بهینه می‌کند تا راندمان بالا و مصرف انرژی کمتری داشته باشد.
# - **اجرای در LabVIEW:**
#   در LabVIEW، می‌توانید از بلوک‌های گرافیکی برای شبیه‌سازی الگوریتم ژنتیک استفاده کنید. خروجی نهایی شامل پارامترهای بهینه‌ی کمپرسور است که می‌تواند برای تنظیمات عملیاتی استفاده شود.
#
# ---
#
# ### **۲. مدل یادگیری تقویتی (Reinforcement Learning) در LabVIEW**
#
# #### **مراحل پیاده‌سازی:**
# 1. **ورودی‌ها:**
#    - **پارامترهای قابل کنترل:**
#      - زاویه‌ی پره‌ها (Blade Angle)
#      - نرخ جریان هوا (Airflow Rate)
#      - نسبت فشار (Pressure Ratio)
#      - دمای ورودی هوا (Inlet Air Temperature)
#      - سرعت چرخش (RPM)
#    - **وضعیت فعلی سیستم:**
#      شامل دما، نسبت فشار، RPM و سایر پارامترهای مشاهده‌شده.
#
# 2. **محیط (Environment):**
#    - محیط شبیه‌سازی‌شده‌ای که عامل (Agent) در آن عمل می‌کند.
#    - مثال:
#      ```plaintext
#      New_Temperature = Current_Temperature + 0.1 * Airflow_Rate - 0.05 * Blade_Angle
#      New_Pressure_Ratio = Current_Pressure_Ratio + 0.02 * Blade_Angle - 0.01 * Airflow_Rate
#      ```
#
# 3. **عامل (Agent):**
#    - عامل تصمیم می‌گیرد که چه عملیاتی (مثل تنظیم زاویه‌ی پره یا نرخ جریان هوا) انجام دهد.
#    - از یک مدل یادگیری تقویتی (مثل PPO) برای آموزش عامل استفاده می‌شود.
#
# 4. **پاداش (Reward):**
#    - عامل بر اساس عملکرد خود (مثل راندمان یا کاهش مصرف انرژی) پاداش دریافت می‌کند.
#    - مثال:
#      ```plaintext
#      Reward = 0.8 * New_Temperature - 0.2 * New_Pressure_Ratio + 0.1 * RPM
#      ```
#
# 5. **خروجی:**
#    - عملیات انجام‌شده، وضعیت فعلی و امتیاز عملکرد (Reward) نمایش داده می‌شود.
#
# #### **پیاده‌سازی در LabVIEW:**
# - **بلوک‌های LabVIEW:**
#   - **State Machine:** برای مدیریت حالت‌های مختلف محیط.
#   - **MathScript Node:** برای پیاده‌سازی مدل یادگیری تقویتی (مثل PPO).
#   - **Data Logging:** برای ذخیره‌ی داده‌های آموزش و تست.
#   - **Graph Indicator:** برای نمایش نتایج (مثل وضعیت فعلی و پاداش).
#
# #### **توضیحات به زبان فارسی:**
# - **هدف:**
#   این مدل یک عامل (Agent) را آموزش می‌دهد تا پارامترهای کمپرسور را به صورت بلادرنگ تنظیم کند و بهترین عملکرد را از سیستم بگیرد.
# - **اجرای در LabVIEW:**
#   در LabVIEW، می‌توانید از بلوک‌های گرافیکی برای شبیه‌سازی محیط و عامل استفاده کنید. خروجی نهایی شامل عملیات انجام‌شده، وضعیت فعلی و امتیاز عملکرد است که می‌تواند برای کنترل بلادرنگ استفاده شود.
#
# ---
#
# ### **مقایسه دو مدل در LabVIEW:**
#
# | ویژگی                  | الگوریتم ژنتیک (GA)                          | یادگیری تقویتی (RL)                     |
# |------------------------|---------------------------------------------|-----------------------------------------|
# | **نوع**               | جستجوی تکاملی                              | یادگیری ماشین                           |
# | **استفاده**           | بهینه‌سازی پارامترها در محیط‌های استاتیک   | کنترل بلادرنگ در محیط‌های پویا          |
# | **سرعت**              | کندتر (به دلیل تکرار نسل‌ها)              | سریع‌تر (یادگیری آنلاین)                |
# | **پیچیدگی**           | ساده‌تر برای پیاده‌سازی                    | نیاز به منابع محاسباتی بیشتر            |
# | **بهترین برای**       | یک‌بار بهینه‌سازی                         | تنظیم پیوسته و بلادرنگ                  |
#
# ---
#
# ### **جمع‌بندی:**
# - **الگوریتم ژنتیک:**
#   این مدل برای یافتن پارامترهای بهینه‌ی ثابت کمپرسور مناسب است و می‌تواند به راحتی در LabVIEW پیاده‌سازی شود. خروجی آن شامل پارامترهای بهینه‌ی کمپرسور است.
#
# - **یادگیری تقویتی:**
#   این مدل برای کنترل بلادرنگ و تنظیم پارامترها در شرایط متغیر مناسب است. در LabVIEW، می‌توانید از این مدل برای کنترل بلادرنگ کمپرسور استفاده کنید.
